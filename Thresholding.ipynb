# %% [markdown]
# # The Effect of Thresholding on Classification
#
# ## The Methods
#
# We first perform some simple thresholding.  The conjecture is that low intensity pixels might cause some fuzzing in the classification process, so we zero out all pixels with value below a certain threshold, and perform classification over all possible threshold values.
#
# ## Environment

# %%
import pandas as pd
pd.options.display.max_rows = 10
pd.options.display.max_columns = 29

import numpy as np

from sklearn import svm, metrics

# %% [markdown]
# ## Simple Thresholding

# %%
raw_st_data = pd.read_csv('train.csv').get_values()
print("Data read complete")
st_train_labels = raw_st_data[:10000,0]
st_test_labels = raw_st_data[10000:11000,0]
metrics_np = np.ndarray(shape=(5,0))
for threshold in range(0, 255):
    st_data = raw_st_data[:11000,1:]
    st_data[st_data < threshold] = 0
    st_train_data = st_data[:10000,:]
    st_test_data = st_data[10000:,:]
    st_classifier = svm.LinearSVC()
    st_classifier.fit(st_train_data, st_train_labels)
    st_predicted_labels = st_classifier.predict(st_test_data)
    labels = np.array(range(0, 10))
    thresholds = np.empty(10)
    thresholds.fill(threshold)
    precision = metrics.precision_score(st_test_labels, st_predicted_labels, average=None)
    recall = metrics.recall_score(st_test_labels, st_predicted_labels, average=None)
    f1 = metrics.f1_score(st_test_labels, st_predicted_labels, average=None)
    scores = np.vstack([thresholds, labels, precision, recall, f1])
    metrics_np = np.concatenate((metrics_np, scores), axis=1)
    print("Finished threshold level %i" % threshold)
    
metrics_df = pd.DataFrame(
    columns = ['threshold', 'label', 'precision', 'recall', 'f1'],
    data = metrics_np.T
)
metrics_df.to_csv('metrics_df.csv')
# Out:
# Finished threshold level 0
# Finished threshold level 1
# Finished threshold level 2
# Finished threshold level 3
# Finished threshold level 4
# Finished threshold level 5
# Finished threshold level 6
# Finished threshold level 7
# Finished threshold level 8
# Finished threshold level 9
# Finished threshold level 10
# Finished threshold level 11
# Finished threshold level 12
# Finished threshold level 13
# Finished threshold level 14
# Finished threshold level 15
# Finished threshold level 16
# Finished threshold level 17
# Finished threshold level 18
# Finished threshold level 19
# Finished threshold level 20
# Finished threshold level 21
# Finished threshold level 22
# Finished threshold level 23
# Finished threshold level 24
# Finished threshold level 25
# Finished threshold level 26
# Finished threshold level 27
# Finished threshold level 28
# Finished threshold level 29
# Finished threshold level 30
# Finished threshold level 31
# Finished threshold level 32
# Finished threshold level 33
# Finished threshold level 34
# Finished threshold level 35
# Finished threshold level 36
# Finished threshold level 37
# Finished threshold level 38
# Finished threshold level 39
# Finished threshold level 40
# Finished threshold level 41
# Finished threshold level 42
# Finished threshold level 43
# Finished threshold level 44
# Finished threshold level 45
# Finished threshold level 46
# Finished threshold level 47
# Finished threshold level 48
# Finished threshold level 49
# Finished threshold level 50
# Finished threshold level 51
# Finished threshold level 52
# Finished threshold level 53
# Finished threshold level 54
# Finished threshold level 55
# Finished threshold level 56
# Finished threshold level 57
# Finished threshold level 58
# Finished threshold level 59
# Finished threshold level 60
# Finished threshold level 61
# Finished threshold level 62
# Finished threshold level 63
# Finished threshold level 64
# Finished threshold level 65
# Finished threshold level 66
# Finished threshold level 67
# Finished threshold level 68
# Finished threshold level 69
# Finished threshold level 70
# Finished threshold level 71
# Finished threshold level 72
# Finished threshold level 73
# Finished threshold level 74
# Finished threshold level 75
# Finished threshold level 76
# Finished threshold level 77
# Finished threshold level 78
# Finished threshold level 79
# Finished threshold level 80
# Finished threshold level 81
# Finished threshold level 82
# Finished threshold level 83
# Finished threshold level 84
# Finished threshold level 85
# Finished threshold level 86
# Finished threshold level 87
# Finished threshold level 88
# Finished threshold level 89
# Finished threshold level 90
# Finished threshold level 91
# Finished threshold level 92
# Finished threshold level 93
# Finished threshold level 94
# Finished threshold level 95
# Finished threshold level 96
# Finished threshold level 97
# Finished threshold level 98
# Finished threshold level 99
# Finished threshold level 100
# Finished threshold level 101
# Finished threshold level 102
# Finished threshold level 103
# Finished threshold level 104
# Finished threshold level 105
# Finished threshold level 106
# Finished threshold level 107
# Finished threshold level 108
# Finished threshold level 109
# Finished threshold level 110
# Finished threshold level 111
# Finished threshold level 112
# Finished threshold level 113
# Finished threshold level 114
# Finished threshold level 115
# Finished threshold level 116
# Finished threshold level 117
# Finished threshold level 118
# Finished threshold level 119
# Finished threshold level 120
# Finished threshold level 121
# Finished threshold level 122
# Finished threshold level 123
# Finished threshold level 124
# Finished threshold level 125
# Finished threshold level 126
# Finished threshold level 127
# Finished threshold level 128
# Finished threshold level 129
# Finished threshold level 130
# Finished threshold level 131
# Finished threshold level 132
# Finished threshold level 133
# Finished threshold level 134
# Finished threshold level 135
# Finished threshold level 136
# Finished threshold level 137
# Finished threshold level 138
# Finished threshold level 139
# Finished threshold level 140
# Finished threshold level 141
# Finished threshold level 142
# Finished threshold level 143
# Finished threshold level 144
# Finished threshold level 145
# Finished threshold level 146
# Finished threshold level 147
# Finished threshold level 148
# Finished threshold level 149
# Finished threshold level 150
# Finished threshold level 151
# Finished threshold level 152
# Finished threshold level 153
# Finished threshold level 154
# Finished threshold level 155
# Finished threshold level 156
# Finished threshold level 157
# Finished threshold level 158
# Finished threshold level 159
# Finished threshold level 160
# Finished threshold level 161
# Finished threshold level 162
# Finished threshold level 163
# Finished threshold level 164
# Finished threshold level 165
# Finished threshold level 166
# Finished threshold level 167
# Finished threshold level 168
# Finished threshold level 169
# Finished threshold level 170
# Finished threshold level 171
# Finished threshold level 172
# Finished threshold level 173
# Finished threshold level 174
# Finished threshold level 175
# Finished threshold level 176
# Finished threshold level 177
# Finished threshold level 178
# Finished threshold level 179
# Finished threshold level 180
# Finished threshold level 181
# Finished threshold level 182
# Finished threshold level 183
# Finished threshold level 184
# Finished threshold level 185
# Finished threshold level 186
# Finished threshold level 187
# Finished threshold level 188
# Finished threshold level 189
# Finished threshold level 190
# Finished threshold level 191
# Finished threshold level 192
# Finished threshold level 193
# Finished threshold level 194
# Finished threshold level 195
# Finished threshold level 196
# Finished threshold level 197
# Finished threshold level 198
# Finished threshold level 199
# Finished threshold level 200
# Finished threshold level 201
# Finished threshold level 202
# Finished threshold level 203
# Finished threshold level 204
# Finished threshold level 205
# Finished threshold level 206
# Finished threshold level 207
# Finished threshold level 208
# Finished threshold level 209
# Finished threshold level 210
# Finished threshold level 211
# Finished threshold level 212
# Finished threshold level 213
# Finished threshold level 214
# Finished threshold level 215
# Finished threshold level 216
# Finished threshold level 217
# Finished threshold level 218
# Finished threshold level 219
# Finished threshold level 220
# Finished threshold level 221
# Finished threshold level 222
# Finished threshold level 223
# Finished threshold level 224
# Finished threshold level 225
# Finished threshold level 226
# Finished threshold level 227
# Finished threshold level 228
# Finished threshold level 229
# Finished threshold level 230
# Finished threshold level 231
# Finished threshold level 232
# Finished threshold level 233
# Finished threshold level 234
# Finished threshold level 235
# Finished threshold level 236
# Finished threshold level 237
# Finished threshold level 238
# Finished threshold level 239
# Finished threshold level 240
# Finished threshold level 241
# Finished threshold level 242
# Finished threshold level 243
# Finished threshold level 244
# Finished threshold level 245
# Finished threshold level 246
# Finished threshold level 247
# Finished threshold level 248
# Finished threshold level 249
# Finished threshold level 250
# Finished threshold level 251
# Finished threshold level 252
# Finished threshold level 253
# Finished threshold level 254

# %% [markdown]
# ## Line Thickness
#
# Our previous attempt at dimensionality reduction by projecting onto the y-axis was less than promising.  One possible explanation is that variations in line thickness could confuse the model.  three methods to address this will be attempted.
#
# ### Averaging
#
# The first two methods involve a pipeline where the first two steps are a simple thresholding, then projection to the y-axis to obtain two vectors of length 28 for each digit.  After that, we try two different averaging methods.  The first is to average by the sum of all pixels, the second is to average over the count of nonzero pixels.  The differences between the results of these methods shed light onto whether pen pressure confuses our models.

# %%
raw_avg_data = pd.read_csv('train.csv').get_values()
print("Data read complete")
avg_train_labels = raw_avg_data[:10000,0]
avg_test_labels = raw_avg_data[10000:11000,0]
avg_metrics_np = np.ndarray(shape=(8,0))
for threshold in range(0, 255):
    print("Threshold: %i" % threshold)
    labels = np.array(range(0, 10))
    thresholds = np.empty(10)
    thresholds.fill(threshold)
    avg_data = raw_avg_data[:11000,1:]
    avg_data[avg_data < threshold] = 0
    count_vector = (avg_data != 0).sum(1) 
    sum_vector = avg_data.sum(1)
    print("Count Vector: %s" % count_vector)
    print("Sum Vector: %s" % sum_vector)
    avg_data = np.reshape(avg_data, (-1,28,28))
    # Y-axis is second axis after reshaping
    avg_data = np.sum(avg_data, axis=2)
    ac_data = avg_data / count_vector[:, None]
    ac_train_data = ac_data[:10000,:]
    ac_test_data = ac_data[10000:,:]
    ac_classifier = svm.LinearSVC()
    ac_classifier.fit(ac_train_data, avg_train_labels)
    ac_predicted_labels = ac_classifier.predict(ac_test_data)
    ac_precision = metrics.precision_score(avg_test_labels, ac_predicted_labels, average=None)
    ac_recall = metrics.recall_score(avg_test_labels, ac_predicted_labels, average=None)
    ac_f1 = metrics.f1_score(avg_test_labels, ac_predicted_labels, average=None)
    as_data = avg_data / sum_vector[:, None]
    as_train_data = as_data[:10000,:]
    as_test_data = as_data[10000:,:]
    as_classifier = svm.LinearSVC()
    as_classifier.fit(as_train_data, avg_train_labels)
    as_predicted_labels = as_classifier.predict(as_test_data)
    as_precision = metrics.precision_score(avg_test_labels, as_predicted_labels, average=None)
    as_recall = metrics.recall_score(avg_test_labels, as_predicted_labels, average=None)
    as_f1 = metrics.f1_score(avg_test_labels, as_predicted_labels, average=None)
    scores = np.vstack([thresholds, labels,
                        ac_precision, ac_recall, ac_f1,
                        as_precision, as_recall, as_f1])
    avg_metrics_np = np.concatenate((avg_metrics_np, scores), axis=1)
    print("Finished threshold level %i" % threshold)
    
avg_metrics_df = pd.DataFrame(
    columns = ['threshold', 'label',
               'precision (count)', 'recall (count)', 'f1 (count)',
               'precision (sum)', 'recall (sum)', 'f1 (sum)'],
    data = avg_metrics_np.T
)
avg_metrics_df.to_csv('avg_metrics_df.csv')
# Out:
# Data read complete
# Threshold: 0
# Count Vector: [ 97 245  79 ..., 169  97 105]
# Sum Vector: [16649 44609 13425 ..., 30499 15915 16540]
# Finished threshold level 0
# Threshold: 1
# Count Vector: [ 97 245  79 ..., 169  97 105]
# Sum Vector: [16649 44609 13425 ..., 30499 15915 16540]
# Finished threshold level 1
# Threshold: 2
# Count Vector: [ 97 242  79 ..., 169  97 105]
# Sum Vector: [16649 44606 13425 ..., 30499 15915 16540]
# /home/swam/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/swam/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Finished threshold level 2
# Threshold: 3
# Count Vector: [ 97 241  79 ..., 168  96 102]
# Sum Vector: [16649 44604 13425 ..., 30497 15913 16534]
# Finished threshold level 3
# Threshold: 4
# Count Vector: [ 97 241  77 ..., 168  96 102]
# Sum Vector: [16649 44604 13419 ..., 30497 15913 16534]
# Finished threshold level 4
# Threshold: 5
# Count Vector: [ 97 241  76 ..., 167  96 101]
# Sum Vector: [16649 44604 13415 ..., 30493 15913 16530]
# Finished threshold level 5
# Threshold: 6
# Count Vector: [ 97 241  76 ..., 166  95 101]
# Sum Vector: [16649 44604 13415 ..., 30488 15908 16530]
# Finished threshold level 6
# Threshold: 7
# Count Vector: [ 97 241  75 ..., 166  95 101]
# Sum Vector: [16649 44604 13409 ..., 30488 15908 16530]
# Finished threshold level 7
# Threshold: 8
# Count Vector: [ 95 240  75 ..., 166  94 100]
# Sum Vector: [16635 44597 13409 ..., 30488 15901 16523]
# Finished threshold level 8
# Threshold: 9
# Count Vector: [ 95 239  73 ..., 166  94 100]
# Sum Vector: [16635 44589 13393 ..., 30488 15901 16523]
# Finished threshold level 9
# Threshold: 10
# Count Vector: [ 95 239  62 ..., 166  94 100]
# Sum Vector: [16635 44589 13294 ..., 30488 15901 16523]
# Finished threshold level 10
# Threshold: 11
# Count Vector: [ 94 239  62 ..., 166  94 100]
# Sum Vector: [16625 44589 13294 ..., 30488 15901 16523]
# Finished threshold level 11
# Threshold: 12
# Count Vector: [ 94 237  62 ..., 166  94 100]
# Sum Vector: [16625 44567 13294 ..., 30488 15901 16523]
# Finished threshold level 12
# Threshold: 13
# Count Vector: [ 94 235  62 ..., 165  94 100]
# Sum Vector: [16625 44543 13294 ..., 30476 15901 16523]
# Finished threshold level 13
# Threshold: 14
# Count Vector: [ 92 233  62 ..., 165  94 100]
# Sum Vector: [16599 44517 13294 ..., 30476 15901 16523]
# Finished threshold level 14
# Threshold: 15
# Count Vector: [ 92 232  62 ..., 165  94 100]
# Sum Vector: [16599 44503 13294 ..., 30476 15901 16523]
# Finished threshold level 15
# Threshold: 16
# Count Vector: [ 91 229  62 ..., 165  94  99]
# Sum Vector: [16584 44458 13294 ..., 30476 15901 16508]
# Finished threshold level 16
# Threshold: 17
# Count Vector: [ 90 227  62 ..., 163  94  98]
# Sum Vector: [16568 44426 13294 ..., 30444 15901 16492]
# Finished threshold level 17
# Threshold: 18
# Count Vector: [ 89 224  62 ..., 163  93  98]
# Sum Vector: [16551 44375 13294 ..., 30444 15884 16492]
# Finished threshold level 18
# Threshold: 19
# Count Vector: [ 89 222  62 ..., 161  92  98]
# Sum Vector: [16551 44339 13294 ..., 30408 15866 16492]
# Finished threshold level 19
# Threshold: 20
# Count Vector: [ 89 221  62 ..., 160  91  98]
# Sum Vector: [16551 44320 13294 ..., 30389 15847 16492]
# Finished threshold level 20
# Threshold: 21
# Count Vector: [ 87 221  62 ..., 158  91  98]
# Sum Vector: [16511 44320 13294 ..., 30349 15847 16492]
# Finished threshold level 21
# Threshold: 22
# Count Vector: [ 87 220  62 ..., 156  90  98]
# Sum Vector: [16511 44299 13294 ..., 30307 15826 16492]
# Finished threshold level 22
# Threshold: 23
# Count Vector: [ 86 220  62 ..., 154  89  98]
# Sum Vector: [16489 44299 13294 ..., 30263 15804 16492]
# Finished threshold level 23
# Threshold: 24
# Count Vector: [ 85 220  62 ..., 154  89  97]
# Sum Vector: [16466 44299 13294 ..., 30263 15804 16469]
# Finished threshold level 24
# Threshold: 25
# Count Vector: [ 85 219  62 ..., 154  89  95]
# Sum Vector: [16466 44275 13294 ..., 30263 15804 16421]
# Finished threshold level 25
# Threshold: 26
# Count Vector: [ 84 218  62 ..., 154  88  95]
# Sum Vector: [16441 44250 13294 ..., 30263 15779 16421]
# Finished threshold level 26
# Threshold: 27
# Count Vector: [ 84 218  62 ..., 154  88  94]
# Sum Vector: [16441 44250 13294 ..., 30263 15779 16395]
# Finished threshold level 27
# Threshold: 28
# Count Vector: [ 83 218  62 ..., 154  88  93]
# Sum Vector: [16414 44250 13294 ..., 30263 15779 16368]
# Finished threshold level 28
# Threshold: 29
# Count Vector: [ 83 218  62 ..., 153  88  92]
# Sum Vector: [16414 44250 13294 ..., 30235 15779 16340]
# Finished threshold level 29
# Threshold: 30
# Count Vector: [ 82 213  62 ..., 153  86  92]
# Sum Vector: [16385 44105 13294 ..., 30235 15721 16340]
# Finished threshold level 30
# Threshold: 31
# Count Vector: [ 82 212  62 ..., 153  86  92]
# Sum Vector: [16385 44075 13294 ..., 30235 15721 16340]
# Finished threshold level 31
# Threshold: 32
# Count Vector: [ 82 211  62 ..., 153  86  91]
# Sum Vector: [16385 44044 13294 ..., 30235 15721 16309]
# Finished threshold level 32
# Threshold: 33
# Count Vector: [ 82 210  62 ..., 153  83  91]
# Sum Vector: [16385 44012 13294 ..., 30235 15625 16309]
# Finished threshold level 33
# Threshold: 34
# Count Vector: [ 82 210  62 ..., 153  80  91]
# Sum Vector: [16385 44012 13294 ..., 30235 15526 16309]
# Finished threshold level 34
# Threshold: 35
# Count Vector: [ 82 209  62 ..., 153  80  91]
# Sum Vector: [16385 43978 13294 ..., 30235 15526 16309]
# Finished threshold level 35
# Threshold: 36
# Count Vector: [ 82 209  62 ..., 153  80  91]
# Sum Vector: [16385 43978 13294 ..., 30235 15526 16309]
# Finished threshold level 36
# Threshold: 37
# Count Vector: [ 82 209  62 ..., 152  80  91]
# Sum Vector: [16385 43978 13294 ..., 30199 15526 16309]
# Finished threshold level 37
# Threshold: 38
# Count Vector: [ 82 209  62 ..., 150  79  90]
# Sum Vector: [16385 43978 13294 ..., 30125 15489 16272]
# Finished threshold level 38
# Threshold: 39
# Count Vector: [ 82 209  62 ..., 150  79  90]
# Sum Vector: [16385 43978 13294 ..., 30125 15489 16272]
# Finished threshold level 39
# Threshold: 40
# Count Vector: [ 82 209  62 ..., 150  78  90]
# Sum Vector: [16385 43978 13294 ..., 30125 15450 16272]
# Finished threshold level 40
# Threshold: 41
# Count Vector: [ 82 209  62 ..., 149  78  90]
# Sum Vector: [16385 43978 13294 ..., 30085 15450 16272]
# Finished threshold level 41
# Threshold: 42
# Count Vector: [ 82 208  62 ..., 149  77  90]
# Sum Vector: [16385 43937 13294 ..., 30085 15409 16272]
# Finished threshold level 42
# Threshold: 43
# Count Vector: [ 82 208  62 ..., 147  76  90]
# Sum Vector: [16385 43937 13294 ..., 30001 15367 16272]
# Finished threshold level 43
# Threshold: 44
# Count Vector: [ 82 208  62 ..., 147  76  90]
# Sum Vector: [16385 43937 13294 ..., 30001 15367 16272]
# Finished threshold level 44
# Threshold: 45
# Count Vector: [ 82 208  62 ..., 147  76  90]
# Sum Vector: [16385 43937 13294 ..., 30001 15367 16272]
# Finished threshold level 45
# Threshold: 46
# Count Vector: [ 82 207  62 ..., 147  76  90]
# Sum Vector: [16385 43892 13294 ..., 30001 15367 16272]
# Finished threshold level 46
# Threshold: 47
# Count Vector: [ 82 207  62 ..., 147  76  89]
# Sum Vector: [16385 43892 13294 ..., 30001 15367 16226]
# Finished threshold level 47
# Threshold: 48
# Count Vector: [ 82 206  62 ..., 147  76  89]
# Sum Vector: [16385 43845 13294 ..., 30001 15367 16226]
# Finished threshold level 48
# Threshold: 49
# Count Vector: [ 82 201  62 ..., 147  76  89]
# Sum Vector: [16385 43605 13294 ..., 30001 15367 16226]
# Finished threshold level 49
# Threshold: 50
# Count Vector: [ 82 201  62 ..., 147  76  89]
# Sum Vector: [16385 43605 13294 ..., 30001 15367 16226]
# Finished threshold level 50
# Threshold: 51
# Count Vector: [ 82 201  62 ..., 146  76  88]
# Sum Vector: [16385 43605 13294 ..., 29951 15367 16176]
# Finished threshold level 51
# Threshold: 52
# Count Vector: [ 82 201  62 ..., 146  76  88]
# Sum Vector: [16385 43605 13294 ..., 29951 15367 16176]
# Finished threshold level 52
# Threshold: 53
# Count Vector: [ 82 201  62 ..., 146  76  88]
# Sum Vector: [16385 43605 13294 ..., 29951 15367 16176]
# Finished threshold level 53
# Threshold: 54
# Count Vector: [ 82 201  62 ..., 146  76  88]
# Sum Vector: [16385 43605 13294 ..., 29951 15367 16176]
# Finished threshold level 54
# Threshold: 55
# Count Vector: [ 81 200  62 ..., 146  76  88]
# Sum Vector: [16331 43551 13294 ..., 29951 15367 16176]
# Finished threshold level 55
# Threshold: 56
# Count Vector: [ 81 200  62 ..., 146  76  87]
# Sum Vector: [16331 43551 13294 ..., 29951 15367 16121]
# Finished threshold level 56
# Threshold: 57
# Count Vector: [ 81 200  62 ..., 146  76  87]
# Sum Vector: [16331 43551 13294 ..., 29951 15367 16121]
# Finished threshold level 57
# Threshold: 58
# Count Vector: [ 81 200  62 ..., 146  76  86]
# Sum Vector: [16331 43551 13294 ..., 29951 15367 16064]
# Finished threshold level 58
# Threshold: 59
# Count Vector: [ 81 200  62 ..., 146  76  86]
# Sum Vector: [16331 43551 13294 ..., 29951 15367 16064]
# Finished threshold level 59
# Threshold: 60
# Count Vector: [ 81 200  62 ..., 146  76  86]
# Sum Vector: [16331 43551 13294 ..., 29951 15367 16064]
# Finished threshold level 60
# Threshold: 61
# Count Vector: [ 81 199  62 ..., 146  76  84]
# Sum Vector: [16331 43491 13294 ..., 29951 15367 15944]
# Finished threshold level 61
# Threshold: 62
# Count Vector: [ 81 198  62 ..., 146  76  84]
# Sum Vector: [16331 43430 13294 ..., 29951 15367 15944]
# Finished threshold level 62
# Threshold: 63
# Count Vector: [ 81 198  61 ..., 146  75  84]
# Sum Vector: [16331 43430 13232 ..., 29951 15305 15944]
# Finished threshold level 63
# Threshold: 64
# Count Vector: [ 81 198  60 ..., 145  75  84]
# Sum Vector: [16331 43430 13169 ..., 29888 15305 15944]
# Finished threshold level 64
# Threshold: 65
# Count Vector: [ 81 197  60 ..., 145  75  84]
# Sum Vector: [16331 43366 13169 ..., 29888 15305 15944]
# Finished threshold level 65
# Threshold: 66
# Count Vector: [ 81 197  60 ..., 145  74  84]
# Sum Vector: [16331 43366 13169 ..., 29888 15240 15944]
# Finished threshold level 66
# Threshold: 67
# Count Vector: [ 81 196  60 ..., 145  74  83]
# Sum Vector: [16331 43300 13169 ..., 29888 15240 15878]
# Finished threshold level 67
# Threshold: 68
# Count Vector: [ 81 195  60 ..., 145  74  83]
# Sum Vector: [16331 43233 13169 ..., 29888 15240 15878]
# Finished threshold level 68
# Threshold: 69
# Count Vector: [ 81 195  60 ..., 144  74  83]
# Sum Vector: [16331 43233 13169 ..., 29820 15240 15878]
# Finished threshold level 69
# Threshold: 70
# Count Vector: [ 81 195  60 ..., 144  73  83]
# Sum Vector: [16331 43233 13169 ..., 29820 15171 15878]
# Finished threshold level 70
# Threshold: 71
# Count Vector: [ 81 194  60 ..., 144  73  83]
# Sum Vector: [16331 43163 13169 ..., 29820 15171 15878]
# Finished threshold level 71
# Threshold: 72
# Count Vector: [ 81 194  60 ..., 144  73  83]
# Sum Vector: [16331 43163 13169 ..., 29820 15171 15878]
# Finished threshold level 72
# Threshold: 73
# Count Vector: [ 81 192  60 ..., 144  73  83]
# Sum Vector: [16331 43019 13169 ..., 29820 15171 15878]
# Finished threshold level 73
# Threshold: 74
# Count Vector: [ 81 192  60 ..., 144  73  83]
# Sum Vector: [16331 43019 13169 ..., 29820 15171 15878]
# Finished threshold level 74
# Threshold: 75
# Count Vector: [ 81 192  60 ..., 144  73  83]
# Sum Vector: [16331 43019 13169 ..., 29820 15171 15878]
# Finished threshold level 75
# Threshold: 76
# Count Vector: [ 81 191  60 ..., 143  73  82]
# Sum Vector: [16331 42944 13169 ..., 29745 15171 15803]
# Finished threshold level 76
# Threshold: 77
# Count Vector: [ 80 189  60 ..., 142  73  81]
# Sum Vector: [16255 42792 13169 ..., 29669 15171 15727]
# Finished threshold level 77
# Threshold: 78
# Count Vector: [ 79 189  60 ..., 142  73  81]
# Sum Vector: [16178 42792 13169 ..., 29669 15171 15727]
# Finished threshold level 78
# Threshold: 79
# Count Vector: [ 79 189  60 ..., 142  73  81]
# Sum Vector: [16178 42792 13169 ..., 29669 15171 15727]
# Finished threshold level 79
# Threshold: 80
# Count Vector: [ 79 189  60 ..., 142  73  81]
# Sum Vector: [16178 42792 13169 ..., 29669 15171 15727]
# Finished threshold level 80
# Threshold: 81
# Count Vector: [ 77 188  60 ..., 139  73  81]
# Sum Vector: [16018 42712 13169 ..., 29429 15171 15727]
# Finished threshold level 81
# Threshold: 82
# Count Vector: [ 76 188  60 ..., 139  71  81]
# Sum Vector: [15937 42712 13169 ..., 29429 15009 15727]
# Finished threshold level 82
# Threshold: 83
# Count Vector: [ 76 188  60 ..., 139  71  80]
# Sum Vector: [15937 42712 13169 ..., 29429 15009 15645]
# Finished threshold level 83
# Threshold: 84
# Count Vector: [ 76 186  60 ..., 139  70  80]
# Sum Vector: [15937 42546 13169 ..., 29429 14926 15645]
# Finished threshold level 84
# Threshold: 85
# Count Vector: [ 76 186  60 ..., 137  70  80]
# Sum Vector: [15937 42546 13169 ..., 29261 14926 15645]
# Finished threshold level 85
# Threshold: 86
# Count Vector: [ 76 185  60 ..., 137  70  80]
# Sum Vector: [15937 42461 13169 ..., 29261 14926 15645]
# Finished threshold level 86
# Threshold: 87
# Count Vector: [ 76 180  60 ..., 137  70  80]
# Sum Vector: [15937 42031 13169 ..., 29261 14926 15645]
# Finished threshold level 87
# Threshold: 88
# Count Vector: [ 76 180  60 ..., 137  70  80]
# Sum Vector: [15937 42031 13169 ..., 29261 14926 15645]
# Finished threshold level 88
# Threshold: 89
# Count Vector: [ 75 180  60 ..., 137  70  80]
# Sum Vector: [15849 42031 13169 ..., 29261 14926 15645]
# Finished threshold level 89
# Threshold: 90
# Count Vector: [ 73 179  59 ..., 137  69  80]
# Sum Vector: [15671 41942 13080 ..., 29261 14837 15645]
# Finished threshold level 90
# Threshold: 91
# Count Vector: [ 73 179  59 ..., 137  69  77]
# Sum Vector: [15671 41942 13080 ..., 29261 14837 15375]
# Finished threshold level 91
# Threshold: 92
# Count Vector: [ 73 179  59 ..., 137  69  76]
# Sum Vector: [15671 41942 13080 ..., 29261 14837 15284]
# Finished threshold level 92
# Threshold: 93
# Count Vector: [ 73 179  59 ..., 136  69  76]
# Sum Vector: [15671 41942 13080 ..., 29169 14837 15284]
# Finished threshold level 93
# Threshold: 94
# Count Vector: [ 70 179  59 ..., 136  69  76]
# Sum Vector: [15392 41942 13080 ..., 29169 14837 15284]
# Finished threshold level 94
# Threshold: 95
# Count Vector: [ 67 178  59 ..., 136  69  75]
# Sum Vector: [15110 41848 13080 ..., 29169 14837 15190]
# Finished threshold level 95
# Threshold: 96
# Count Vector: [ 66 178  59 ..., 136  69  75]
# Sum Vector: [15015 41848 13080 ..., 29169 14837 15190]
# Finished threshold level 96
# Threshold: 97
# Count Vector: [ 66 178  59 ..., 135  69  75]
# Sum Vector: [15015 41848 13080 ..., 29073 14837 15190]
# Finished threshold level 97
# Threshold: 98
# Count Vector: [ 66 178  59 ..., 134  69  75]
# Sum Vector: [15015 41848 13080 ..., 28976 14837 15190]
# Finished threshold level 98
# Threshold: 99
# Count Vector: [ 66 178  59 ..., 134  67  74]
# Sum Vector: [15015 41848 13080 ..., 28976 14641 15092]
# Finished threshold level 99
# Threshold: 100
# Count Vector: [ 66 178  59 ..., 132  67  74]
# Sum Vector: [15015 41848 13080 ..., 28778 14641 15092]
# Finished threshold level 100
# Threshold: 101
# Count Vector: [ 66 178  59 ..., 131  67  74]
# Sum Vector: [15015 41848 13080 ..., 28678 14641 15092]
# Finished threshold level 101
# Threshold: 102
# Count Vector: [ 66 178  59 ..., 131  66  74]
# Sum Vector: [15015 41848 13080 ..., 28678 14540 15092]
# Finished threshold level 102
# Threshold: 103
# Count Vector: [ 66 178  59 ..., 131  66  74]
# Sum Vector: [15015 41848 13080 ..., 28678 14540 15092]
# Finished threshold level 103
# Threshold: 104
# Count Vector: [ 65 178  59 ..., 131  65  74]
# Sum Vector: [14912 41848 13080 ..., 28678 14437 15092]
# Finished threshold level 104
# Threshold: 105
# Count Vector: [ 65 177  59 ..., 130  65  74]
# Sum Vector: [14912 41744 13080 ..., 28574 14437 15092]
# Finished threshold level 105
# Threshold: 106
# Count Vector: [ 65 177  59 ..., 129  64  73]
# Sum Vector: [14912 41744 13080 ..., 28469 14332 14987]
# Finished threshold level 106
# Threshold: 107
# Count Vector: [ 65 177  58 ..., 128  64  72]
# Sum Vector: [14912 41744 12974 ..., 28363 14332 14881]
# Finished threshold level 107
# Threshold: 108
# Count Vector: [ 65 177  58 ..., 127  64  72]
# Sum Vector: [14912 41744 12974 ..., 28256 14332 14881]
# Finished threshold level 108
# Threshold: 109
# Count Vector: [ 65 177  58 ..., 127  64  72]
# Sum Vector: [14912 41744 12974 ..., 28256 14332 14881]
# Finished threshold level 109
# Threshold: 110
# Count Vector: [ 65 176  58 ..., 125  64  72]
# Sum Vector: [14912 41635 12974 ..., 28038 14332 14881]
# Finished threshold level 110
# Threshold: 111
# Count Vector: [ 65 176  58 ..., 123  64  71]
# Sum Vector: [14912 41635 12974 ..., 27818 14332 14771]
# Finished threshold level 111
# Threshold: 112
# Count Vector: [ 65 176  58 ..., 123  64  71]
# Sum Vector: [14912 41635 12974 ..., 27818 14332 14771]
# Finished threshold level 112
# Threshold: 113
# Count Vector: [ 65 176  58 ..., 123  64  71]
# Sum Vector: [14912 41635 12974 ..., 27818 14332 14771]
# Finished threshold level 113
# Threshold: 114
# Count Vector: [ 65 176  58 ..., 123  64  71]
# Sum Vector: [14912 41635 12974 ..., 27818 14332 14771]
# Finished threshold level 114
# Threshold: 115
# Count Vector: [ 65 175  58 ..., 123  63  71]
# Sum Vector: [14912 41521 12974 ..., 27818 14218 14771]
# Finished threshold level 115
# Threshold: 116
# Count Vector: [ 65 175  58 ..., 122  63  71]
# Sum Vector: [14912 41521 12974 ..., 27703 14218 14771]
# Finished threshold level 116
# Threshold: 117
# Count Vector: [ 65 175  58 ..., 122  63  71]
# Sum Vector: [14912 41521 12974 ..., 27703 14218 14771]
# Finished threshold level 117
# Threshold: 118
# Count Vector: [ 65 175  58 ..., 122  63  71]
# Sum Vector: [14912 41521 12974 ..., 27703 14218 14771]
# Finished threshold level 118
# Threshold: 119
# Count Vector: [ 65 175  58 ..., 121  63  71]
# Sum Vector: [14912 41521 12974 ..., 27585 14218 14771]
# Finished threshold level 119
# Threshold: 120
# Count Vector: [ 65 175  58 ..., 121  63  70]
# Sum Vector: [14912 41521 12974 ..., 27585 14218 14652]
# Finished threshold level 120
# Threshold: 121
# Count Vector: [ 65 175  58 ..., 121  63  70]
# Sum Vector: [14912 41521 12974 ..., 27585 14218 14652]
# Finished threshold level 121
# Threshold: 122
# Count Vector: [ 65 175  58 ..., 121  63  70]
# Sum Vector: [14912 41521 12974 ..., 27585 14218 14652]
# Finished threshold level 122
# Threshold: 123
# Count Vector: [ 65 175  58 ..., 121  63  69]
# Sum Vector: [14912 41521 12974 ..., 27585 14218 14530]
# Finished threshold level 123
# Threshold: 124
# Count Vector: [ 64 175  58 ..., 121  63  69]
# Sum Vector: [14789 41521 12974 ..., 27585 14218 14530]
# Finished threshold level 124
# Threshold: 125
# Count Vector: [ 64 175  58 ..., 121  62  69]
# Sum Vector: [14789 41521 12974 ..., 27585 14094 14530]
# Finished threshold level 125
# Threshold: 126
# Count Vector: [ 64 175  58 ..., 121  61  68]
# Sum Vector: [14789 41521 12974 ..., 27585 13969 14405]
# Finished threshold level 126
# Threshold: 127
# Count Vector: [ 64 175  58 ..., 121  61  68]
# Sum Vector: [14789 41521 12974 ..., 27585 13969 14405]
# Finished threshold level 127
# Threshold: 128
# Count Vector: [ 64 175  58 ..., 119  60  68]
# Sum Vector: [14789 41521 12974 ..., 27331 13842 14405]
# Finished threshold level 128
# Threshold: 129
# Count Vector: [ 64 174  58 ..., 119  60  66]
# Sum Vector: [14789 41393 12974 ..., 27331 13842 14149]
# Finished threshold level 129
# Threshold: 130
# Count Vector: [ 64 174  58 ..., 118  60  66]
# Sum Vector: [14789 41393 12974 ..., 27202 13842 14149]
# Finished threshold level 130
# Threshold: 131
# Count Vector: [ 64 174  58 ..., 117  60  66]
# Sum Vector: [14789 41393 12974 ..., 27072 13842 14149]
# Finished threshold level 131
# Threshold: 132
# Count Vector: [ 63 174  58 ..., 117  60  66]
# Sum Vector: [14658 41393 12974 ..., 27072 13842 14149]
# Finished threshold level 132
# Threshold: 133
# Count Vector: [ 63 174  58 ..., 116  58  65]
# Sum Vector: [14658 41393 12974 ..., 26940 13578 14017]
# Finished threshold level 133
# Threshold: 134
# Count Vector: [ 63 174  58 ..., 116  58  64]
# Sum Vector: [14658 41393 12974 ..., 26940 13578 13884]
# Finished threshold level 134
# Threshold: 135
# Count Vector: [ 63 174  58 ..., 116  57  62]
# Sum Vector: [14658 41393 12974 ..., 26940 13444 13616]
# Finished threshold level 135
# Threshold: 136
# Count Vector: [ 63 174  58 ..., 115  57  62]
# Sum Vector: [14658 41393 12974 ..., 26805 13444 13616]
# Finished threshold level 136
# Threshold: 137
# Count Vector: [ 63 174  58 ..., 115  57  62]
# Sum Vector: [14658 41393 12974 ..., 26805 13444 13616]
# Finished threshold level 137
# Threshold: 138
# Count Vector: [ 63 172  58 ..., 115  57  62]
# Sum Vector: [14658 41119 12974 ..., 26805 13444 13616]
# Finished threshold level 138
# Threshold: 139
# Count Vector: [ 63 172  58 ..., 114  57  62]
# Sum Vector: [14658 41119 12974 ..., 26667 13444 13616]
# Finished threshold level 139
# Threshold: 140
# Count Vector: [ 63 172  57 ..., 114  56  62]
# Sum Vector: [14658 41119 12835 ..., 26667 13305 13616]
# Finished threshold level 140
# Threshold: 141
# Count Vector: [ 63 172  57 ..., 113  56  61]
# Sum Vector: [14658 41119 12835 ..., 26527 13305 13476]
# Finished threshold level 141
# Threshold: 142
# Count Vector: [ 63 172  56 ..., 112  56  61]
# Sum Vector: [14658 41119 12694 ..., 26386 13305 13476]
# Finished threshold level 142
# Threshold: 143
# Count Vector: [ 63 172  56 ..., 112  56  61]
# Sum Vector: [14658 41119 12694 ..., 26386 13305 13476]
# Finished threshold level 143
# Threshold: 144
# Count Vector: [ 63 172  56 ..., 112  56  61]
# Sum Vector: [14658 41119 12694 ..., 26386 13305 13476]
# Finished threshold level 144
# Threshold: 145
# Count Vector: [ 63 172  56 ..., 112  56  61]
# Sum Vector: [14658 41119 12694 ..., 26386 13305 13476]
# Finished threshold level 145
# Threshold: 146
# Count Vector: [ 63 172  56 ..., 112  56  61]
# Sum Vector: [14658 41119 12694 ..., 26386 13305 13476]
# Finished threshold level 146
# Threshold: 147
# Count Vector: [ 63 170  55 ..., 112  56  61]
# Sum Vector: [14658 40827 12548 ..., 26386 13305 13476]
# Finished threshold level 147
# Threshold: 148
# Count Vector: [ 63 168  55 ..., 111  56  61]
# Sum Vector: [14658 40533 12548 ..., 26239 13305 13476]
# Finished threshold level 148
# Threshold: 149
# Count Vector: [ 63 168  55 ..., 111  55  60]
# Sum Vector: [14658 40533 12548 ..., 26239 13157 13328]
# Finished threshold level 149
# Threshold: 150
# Count Vector: [ 63 168  55 ..., 111  55  60]
# Sum Vector: [14658 40533 12548 ..., 26239 13157 13328]
# Finished threshold level 150
# Threshold: 151
# Count Vector: [ 63 167  55 ..., 110  55  60]
# Sum Vector: [14658 40383 12548 ..., 26089 13157 13328]
# Finished threshold level 151
# Threshold: 152
# Count Vector: [ 63 166  55 ..., 110  55  60]
# Sum Vector: [14658 40232 12548 ..., 26089 13157 13328]
# Finished threshold level 152
# Threshold: 153
# Count Vector: [ 63 166  55 ..., 110  55  60]
# Sum Vector: [14658 40232 12548 ..., 26089 13157 13328]
# Finished threshold level 153
# Threshold: 154
# Count Vector: [ 63 164  55 ..., 109  55  60]
# Sum Vector: [14658 39926 12548 ..., 25936 13157 13328]
# Finished threshold level 154
# Threshold: 155
# Count Vector: [ 63 164  55 ..., 109  55  60]
# Sum Vector: [14658 39926 12548 ..., 25936 13157 13328]
# Finished threshold level 155
# Threshold: 156
# Count Vector: [ 63 164  55 ..., 109  55  60]
# Sum Vector: [14658 39926 12548 ..., 25936 13157 13328]
# Finished threshold level 156
# Threshold: 157
# Count Vector: [ 63 164  54 ..., 109  54  60]
# Sum Vector: [14658 39926 12392 ..., 25936 13001 13328]
# Finished threshold level 157
# Threshold: 158
# Count Vector: [ 63 164  54 ..., 109  54  59]
# Sum Vector: [14658 39926 12392 ..., 25936 13001 13171]
# Finished threshold level 158
# Threshold: 159
# Count Vector: [ 63 164  54 ..., 109  54  59]
# Sum Vector: [14658 39926 12392 ..., 25936 13001 13171]
# Finished threshold level 159
# Threshold: 160
# Count Vector: [ 62 164  54 ..., 108  54  59]
# Sum Vector: [14499 39926 12392 ..., 25777 13001 13171]
# Finished threshold level 160
# Threshold: 161
# Count Vector: [ 62 164  54 ..., 108  54  59]
# Sum Vector: [14499 39926 12392 ..., 25777 13001 13171]
# Finished threshold level 161
# Threshold: 162
# Count Vector: [ 62 163  54 ..., 108  54  58]
# Sum Vector: [14499 39765 12392 ..., 25777 13001 13010]
# Finished threshold level 162
# Threshold: 163
# Count Vector: [ 62 163  54 ..., 108  54  57]
# Sum Vector: [14499 39765 12392 ..., 25777 13001 12848]
# Finished threshold level 163
# Threshold: 164
# Count Vector: [ 62 162  54 ..., 107  54  57]
# Sum Vector: [14499 39602 12392 ..., 25614 13001 12848]
# Finished threshold level 164
# Threshold: 165
# Count Vector: [ 62 162  54 ..., 107  54  52]
# Sum Vector: [14499 39602 12392 ..., 25614 13001 12028]
# Finished threshold level 165
# Threshold: 166
# Count Vector: [ 62 162  54 ..., 106  54  51]
# Sum Vector: [14499 39602 12392 ..., 25449 13001 11863]
# Finished threshold level 166
# Threshold: 167
# Count Vector: [ 62 161  54 ..., 106  54  51]
# Sum Vector: [14499 39436 12392 ..., 25449 13001 11863]
# Finished threshold level 167
# Threshold: 168
# Count Vector: [ 61 161  54 ..., 106  54  51]
# Sum Vector: [14332 39436 12392 ..., 25449 13001 11863]
# Finished threshold level 168
# Threshold: 169
# Count Vector: [ 60 161  54 ..., 105  54  50]
# Sum Vector: [14164 39436 12392 ..., 25281 13001 11695]
# Finished threshold level 169
# Threshold: 170
# Count Vector: [ 60 161  54 ..., 104  54  50]
# Sum Vector: [14164 39436 12392 ..., 25112 13001 11695]
# Finished threshold level 170
# Threshold: 171
# Count Vector: [ 59 161  54 ..., 104  54  50]
# Sum Vector: [13994 39436 12392 ..., 25112 13001 11695]
# Finished threshold level 171
# Threshold: 172
# Count Vector: [ 59 159  54 ..., 104  54  50]
# Sum Vector: [13994 39094 12392 ..., 25112 13001 11695]
# Finished threshold level 172
# Threshold: 173
# Count Vector: [ 59 158  54 ..., 103  54  50]
# Sum Vector: [13994 38922 12392 ..., 24940 13001 11695]
# Finished threshold level 173
# Threshold: 174
# Count Vector: [ 59 158  54 ..., 103  54  50]
# Sum Vector: [13994 38922 12392 ..., 24940 13001 11695]
# Finished threshold level 174
# Threshold: 175
# Count Vector: [ 59 157  54 ..., 102  54  49]
# Sum Vector: [13994 38748 12392 ..., 24766 13001 11521]
# Finished threshold level 175
# Threshold: 176
# Count Vector: [ 59 157  54 ..., 102  54  49]
# Sum Vector: [13994 38748 12392 ..., 24766 13001 11521]
# Finished threshold level 176
# Threshold: 177
# Count Vector: [ 59 157  54 ..., 102  54  49]
# Sum Vector: [13994 38748 12392 ..., 24766 13001 11521]
# Finished threshold level 177
# Threshold: 178
# Count Vector: [ 59 157  54 ..., 102  54  49]
# Sum Vector: [13994 38748 12392 ..., 24766 13001 11521]
# Finished threshold level 178
# Threshold: 179
# Count Vector: [ 59 157  54 ..., 102  53  49]
# Sum Vector: [13994 38748 12392 ..., 24766 12823 11521]
# Finished threshold level 179
# Threshold: 180
# Count Vector: [ 59 156  54 ..., 102  53  45]
# Sum Vector: [13994 38569 12392 ..., 24766 12823 10805]
# Finished threshold level 180
# Threshold: 181
# Count Vector: [ 59 156  54 ..., 102  53  44]
# Sum Vector: [13994 38569 12392 ..., 24766 12823 10625]
# Finished threshold level 181
# Threshold: 182
# Count Vector: [ 59 156  54 ..., 102  53  44]
# Sum Vector: [13994 38569 12392 ..., 24766 12823 10625]
# Finished threshold level 182
# Threshold: 183
# Count Vector: [ 59 155  54 ..., 102  53  44]
# Sum Vector: [13994 38387 12392 ..., 24766 12823 10625]
# Finished threshold level 183
# Threshold: 184
# Count Vector: [ 59 155  54 ..., 100  53  44]
# Sum Vector: [13994 38387 12392 ..., 24400 12823 10625]
# Finished threshold level 184
# Threshold: 185
# Count Vector: [ 59 155  39 ..., 100  53  44]
# Sum Vector: [13994 38387  9632 ..., 24400 12823 10625]
# Finished threshold level 185
# Threshold: 186
# Count Vector: [ 59 155  35 ..., 100  53  44]
# Sum Vector: [13994 38387  8892 ..., 24400 12823 10625]
# Finished threshold level 186
# Threshold: 187
# Count Vector: [ 59 154  35 ..., 100  53  44]
# Sum Vector: [13994 38201  8892 ..., 24400 12823 10625]
# Finished threshold level 187
# Threshold: 188
# Count Vector: [ 59 154  35 ...,  99  52  44]
# Sum Vector: [13994 38201  8892 ..., 24213 12636 10625]
# Finished threshold level 188
# Threshold: 189
# Count Vector: [ 57 154  35 ...,  99  51  44]
# Sum Vector: [13618 38201  8892 ..., 24213 12448 10625]
# Finished threshold level 189
# Threshold: 190
# Count Vector: [ 57 154  35 ...,  98  50  44]
# Sum Vector: [13618 38201  8892 ..., 24024 12259 10625]
# Finished threshold level 190
# Threshold: 191
# Count Vector: [ 57 154  35 ...,  98  50  44]
# Sum Vector: [13618 38201  8892 ..., 24024 12259 10625]
# Finished threshold level 191
# Threshold: 192
# Count Vector: [ 55 153  35 ...,  98  50  42]
# Sum Vector: [13236 38010  8892 ..., 24024 12259 10243]
# Finished threshold level 192
# Threshold: 193
# Count Vector: [ 55 152  35 ...,  98  49  42]
# Sum Vector: [13236 37818  8892 ..., 24024 12067 10243]
# Finished threshold level 193
# Threshold: 194
# Count Vector: [ 55 152  35 ...,  98  49  42]
# Sum Vector: [13236 37818  8892 ..., 24024 12067 10243]
# Finished threshold level 194
# Threshold: 195
# Count Vector: [ 55 151  35 ...,  98  49  42]
# Sum Vector: [13236 37624  8892 ..., 24024 12067 10243]
# Finished threshold level 195
# Threshold: 196
# Count Vector: [ 54 151  35 ...,  98  49  42]
# Sum Vector: [13041 37624  8892 ..., 24024 12067 10243]
# Finished threshold level 196
# Threshold: 197
# Count Vector: [ 53 151  35 ...,  97  49  42]
# Sum Vector: [12845 37624  8892 ..., 23828 12067 10243]
# Finished threshold level 197
# Threshold: 198
# Count Vector: [ 53 151  35 ...,  97  49  42]
# Sum Vector: [12845 37624  8892 ..., 23828 12067 10243]
# Finished threshold level 198
# Threshold: 199
# Count Vector: [ 52 151  35 ...,  97  49  42]
# Sum Vector: [12647 37624  8892 ..., 23828 12067 10243]
# Finished threshold level 199
# Threshold: 200
# Count Vector: [ 52 150  35 ...,  97  48  42]
# Sum Vector: [12647 37425  8892 ..., 23828 11868 10243]
# Finished threshold level 200
# Threshold: 201
# Count Vector: [ 52 148  35 ...,  97  48  42]
# Sum Vector: [12647 37025  8892 ..., 23828 11868 10243]
# Finished threshold level 201
# Threshold: 202
# Count Vector: [ 52 148  35 ...,  97  48  42]
# Sum Vector: [12647 37025  8892 ..., 23828 11868 10243]
# Finished threshold level 202
# Threshold: 203
# Count Vector: [ 52 146  35 ...,  97  48  41]
# Sum Vector: [12647 36621  8892 ..., 23828 11868 10041]
# Finished threshold level 203
# Threshold: 204
# Count Vector: [ 51 146  35 ...,  97  48  40]
# Sum Vector: [12444 36621  8892 ..., 23828 11868  9838]
# Finished threshold level 204
# Threshold: 205
# Count Vector: [ 51 146  35 ...,  97  47  40]
# Sum Vector: [12444 36621  8892 ..., 23828 11664  9838]
# Finished threshold level 205
# Threshold: 206
# Count Vector: [ 51 146  35 ...,  97  47  40]
# Sum Vector: [12444 36621  8892 ..., 23828 11664  9838]
# Finished threshold level 206
# Threshold: 207
# Count Vector: [ 50 145  35 ...,  97  47  40]
# Sum Vector: [12238 36415  8892 ..., 23828 11664  9838]
# Finished threshold level 207
# Threshold: 208
# Count Vector: [ 49 145  35 ...,  97  47  39]
# Sum Vector: [12031 36415  8892 ..., 23828 11664  9631]
# Finished threshold level 208
# Threshold: 209
# Count Vector: [ 48 145  35 ...,  97  47  39]
# Sum Vector: [11823 36415  8892 ..., 23828 11664  9631]
# Finished threshold level 209
# Threshold: 210
# Count Vector: [ 46 143  35 ...,  96  47  39]
# Sum Vector: [11405 35997  8892 ..., 23619 11664  9631]
# Finished threshold level 210
# Threshold: 211
# Count Vector: [ 45 143  35 ...,  96  47  39]
# Sum Vector: [11195 35997  8892 ..., 23619 11664  9631]
# Finished threshold level 211
# Threshold: 212
# Count Vector: [ 45 143  35 ...,  92  47  39]
# Sum Vector: [11195 35997  8892 ..., 22775 11664  9631]
# Finished threshold level 212
# Threshold: 213
# Count Vector: [ 45 141  35 ...,  90  47  38]
# Sum Vector: [11195 35573  8892 ..., 22351 11664  9419]
# Finished threshold level 213
# Threshold: 214
# Count Vector: [ 45 141  35 ...,  90  46  38]
# Sum Vector: [11195 35573  8892 ..., 22351 11451  9419]
# Finished threshold level 214
# Threshold: 215
# Count Vector: [ 44 141  35 ...,  90  46  38]
# Sum Vector: [10981 35573  8892 ..., 22351 11451  9419]
# Finished threshold level 215
# Threshold: 216
# Count Vector: [ 44 141  35 ...,  90  46  38]
# Sum Vector: [10981 35573  8892 ..., 22351 11451  9419]
# Finished threshold level 216
# Threshold: 217
# Count Vector: [ 44 141  35 ...,  90  46  38]
# Sum Vector: [10981 35573  8892 ..., 22351 11451  9419]
# Finished threshold level 217
# Threshold: 218
# Count Vector: [ 44 140  35 ...,  89  46  38]
# Sum Vector: [10981 35356  8892 ..., 22134 11451  9419]
# Finished threshold level 218
# Threshold: 219
# Count Vector: [ 43 140  35 ...,  89  46  38]
# Sum Vector: [10763 35356  8892 ..., 22134 11451  9419]
# Finished threshold level 219
# Threshold: 220
# Count Vector: [ 43 140  35 ...,  89  46  38]
# Sum Vector: [10763 35356  8892 ..., 22134 11451  9419]
# Finished threshold level 220
# Threshold: 221
# Count Vector: [ 42 140  35 ...,  89  46  37]
# Sum Vector: [10543 35356  8892 ..., 22134 11451  9199]
# Finished threshold level 221
# Threshold: 222
# Count Vector: [ 42 140  35 ...,  89  45  36]
# Sum Vector: [10543 35356  8892 ..., 22134 11230  8978]
# Finished threshold level 222
# Threshold: 223
# Count Vector: [ 42 140  35 ...,  89  45  36]
# Sum Vector: [10543 35356  8892 ..., 22134 11230  8978]
# Finished threshold level 223
# Threshold: 224
# Count Vector: [ 42 140  35 ...,  87  45  36]
# Sum Vector: [10543 35356  8892 ..., 21688 11230  8978]
# Finished threshold level 224
# Threshold: 225
# Count Vector: [ 42 139  35 ...,  87  43  35]
# Sum Vector: [10543 35132  8892 ..., 21688 10782  8754]
# Finished threshold level 225
# Threshold: 226
# Count Vector: [ 42 139  35 ...,  87  43  34]
# Sum Vector: [10543 35132  8892 ..., 21688 10782  8529]
# Finished threshold level 226
# Threshold: 227
# Count Vector: [ 42 139  35 ...,  86  43  34]
# Sum Vector: [10543 35132  8892 ..., 21462 10782  8529]
# Finished threshold level 227
# Threshold: 228
# Count Vector: [ 42 139  35 ...,  85  43  34]
# Sum Vector: [10543 35132  8892 ..., 21235 10782  8529]
# Finished threshold level 228
# Threshold: 229
# Count Vector: [ 42 139  35 ...,  85  43  33]
# Sum Vector: [10543 35132  8892 ..., 21235 10782  8301]
# Finished threshold level 229
# Threshold: 230
# Count Vector: [ 42 139  35 ...,  85  43  33]
# Sum Vector: [10543 35132  8892 ..., 21235 10782  8301]
# Finished threshold level 230
# Threshold: 231
# Count Vector: [ 42 139  35 ...,  85  42  33]
# Sum Vector: [10543 35132  8892 ..., 21235 10552  8301]
# Finished threshold level 231
# Threshold: 232
# Count Vector: [ 42 138  35 ...,  83  42  33]
# Sum Vector: [10543 34901  8892 ..., 20773 10552  8301]
# Finished threshold level 232
# Threshold: 233
# Count Vector: [ 42 137  35 ...,  81  42  33]
# Sum Vector: [10543 34669  8892 ..., 20309 10552  8301]
# Finished threshold level 233
# Threshold: 234
# Count Vector: [ 42 136  35 ...,  79  42  33]
# Sum Vector: [10543 34436  8892 ..., 19843 10552  8301]
# Finished threshold level 234
# Threshold: 235
# Count Vector: [ 42 136  35 ...,  79  42  32]
# Sum Vector: [10543 34436  8892 ..., 19843 10552  8067]
# Finished threshold level 235
# Threshold: 236
# Count Vector: [ 41 136  35 ...,  77  42  32]
# Sum Vector: [10308 34436  8892 ..., 19373 10552  8067]
# Finished threshold level 236
# Threshold: 237
# Count Vector: [ 41 136  35 ...,  77  42  32]
# Sum Vector: [10308 34436  8892 ..., 19373 10552  8067]
# Finished threshold level 237
# Threshold: 238
# Count Vector: [ 41 136  35 ...,  77  41  31]
# Sum Vector: [10308 34436  8892 ..., 19373 10315  7830]
# Finished threshold level 238
# Threshold: 239
# Count Vector: [ 40 136  35 ...,  77  39  31]
# Sum Vector: [10070 34436  8892 ..., 19373  9839  7830]
# Finished threshold level 239
# Threshold: 240
# Count Vector: [ 40 135  35 ...,  76  38  31]
# Sum Vector: [10070 34197  8892 ..., 19134  9600  7830]
# Finished threshold level 240
# Threshold: 241
# Count Vector: [ 38 133  35 ...,  76  38  29]
# Sum Vector: [ 9590 33717  8892 ..., 19134  9600  7350]
# Finished threshold level 241
# Threshold: 242
# Count Vector: [ 38 133  35 ...,  76  38  29]
# Sum Vector: [ 9590 33717  8892 ..., 19134  9600  7350]
# Finished threshold level 242
# Threshold: 243
# Count Vector: [ 38 133  35 ...,  75  38  29]
# Sum Vector: [ 9590 33717  8892 ..., 18892  9600  7350]
# Finished threshold level 243
# Threshold: 244
# Count Vector: [ 38 129  35 ...,  75  38  29]
# Sum Vector: [ 9590 32745  8892 ..., 18892  9600  7350]
# Finished threshold level 244
# Threshold: 245
# Count Vector: [ 38 129  35 ...,  74  38  29]
# Sum Vector: [ 9590 32745  8892 ..., 18648  9600  7350]
# Finished threshold level 245
# Threshold: 246
# Count Vector: [ 37 128  35 ...,  72  37  29]
# Sum Vector: [ 9345 32500  8892 ..., 18158  9355  7350]
# Finished threshold level 246
# Threshold: 247
# Count Vector: [ 37 127  35 ...,  72  37  29]
# Sum Vector: [ 9345 32254  8892 ..., 18158  9355  7350]
# Finished threshold level 247
# Threshold: 248
# Count Vector: [ 36 127  35 ...,  71  37  29]
# Sum Vector: [ 9098 32254  8892 ..., 17911  9355  7350]
# Finished threshold level 248
# Threshold: 249
# Count Vector: [ 34 127  35 ...,  71  36  28]
# Sum Vector: [ 8602 32254  8892 ..., 17911  9107  7102]
# Finished threshold level 249
# Threshold: 250
# Count Vector: [ 34 127  35 ...,  69  36  27]
# Sum Vector: [ 8602 32254  8892 ..., 17413  9107  6853]
# Finished threshold level 250
# Threshold: 251
# Count Vector: [ 32 126  35 ...,  68  35  26]
# Sum Vector: [ 8102 32004  8892 ..., 17163  8857  6603]
# Finished threshold level 251
# Threshold: 252
# Count Vector: [ 31 126  35 ...,  66  35  26]
# Sum Vector: [ 7851 32004  8892 ..., 16661  8857  6603]
# Finished threshold level 252
# Threshold: 253
# Count Vector: [ 31 125  35 ...,  24  35  25]
# Sum Vector: [ 7851 31752  8892 ...,  6077  8857  6351]
# Finished threshold level 253
# Threshold: 254
# Count Vector: [  7 125  35 ...,   3   1  25]
# Sum Vector: [ 1779 31752  8892 ...,   764   255  6351]
# Finished threshold level 254

# %% [markdown]
# ## Double Threshold
#
# The next method takes thresholding to the next level.  We threshold over two axes: pixel-intensity and nonzero-count.  At each nonzero-count level, we pixel-intensity threshold each digit until the nonzero-count is reached.  This method will need to be refined, and probably pushed into another notebook.
